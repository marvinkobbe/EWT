# %%
import sys
sys.path.insert(0, '..')  # Füge das übergeordnete Verzeichnis zum Python-Pfad hinzu

# Lade Modul neu, um Änderungen zu übernehmen
import importlib
if 'utils_functions' in sys.modules:
    importlib.reload(sys.modules['utils_functions'])

from utils_functions import to_float_array, df_d0, dataframe1, fit_exponential_decay, plot_data_with_fits, plot_parameter_histograms, fit_linear, plot_linear_fits, plot_slope_histogram
import glob
import os
import pandas as pd
from IPython.display import display
import numpy as np
# Out:
# Funktionen erfolgreich definiert:
# 1. fit_exponential_decay(data_frames)
# 2. plot_data_with_fits(results, title, save_path, uniform_axes)
# 3. plot_parameter_histograms(results, save_path, figsize)
# 4. fit_linear(data_frames)
# 5. plot_linear_fits(results, title, save_path, uniform_axes)
# 6. plot_slope_histogram(results, save_path, figsize)

# %%
# MCT1 Data laden
data_path1 = '/workspaces/EWT/EWT4/DATA/ETW4.ods'
df_E_MCT1_ilacco1_0 = pd.read_excel(data_path1, engine='odf', sheet_name="Sheet11", skiprows=36)
df_E_MCT1_ilacco1_0_50µM_CCCP = pd.read_excel(data_path1, engine='odf', sheet_name="Sheet4", skiprows=36)
df_E_MCT1_ilacco1_1 = pd.read_excel(data_path1, engine='odf', sheet_name="Sheet12", skiprows=36)
df_E_MCT1_ilacco1_2 = pd.read_excel(data_path1, engine='odf', sheet_name="Sheet15", skiprows=36)
df_E_MCT1_ilacco1_1_50µM_CCCP = pd.read_excel(data_path1, engine='odf', sheet_name="Sheet16", skiprows=36)

E_MCT1_ilacco1_0 = dataframe1(df_E_MCT1_ilacco1_0,3,5,6,7)
E_MCT1_ilacco1_0_50μM_CCCP = dataframe1(df_E_MCT1_ilacco1_0_50μM_CCCP,3,8,9,10)
E_MCT1_ilacco1_1 = dataframe1(df_E_MCT1_ilacco1_1,3,5,6,7)
E_MCT1_ilacco1_2 = dataframe1(df_E_MCT1_ilacco1_2,3,5,6,7)
E_MCT1_ilacco1_1_50μM_CCCP = dataframe1(df_E_MCT1_ilacco1_1_50μM_CCCP,3,5,6,7)
print(E_MCT1_ilacco1_0)
# Out:
#      Time  1.Messung  2.Messung  3.Messung  Mittelwerte  Standardabweichung
# 0     0.0   0.000000   0.000000   0.000000     0.000000            0.000000
# 1    10.0  -0.021960  -0.034363  -0.047001    -0.034441            0.012521
# 2    20.0  -0.029753  -0.052886  -0.071809    -0.051483            0.021063
# 3    30.0  -0.026413  -0.064880  -0.088356    -0.059883            0.031272
# 4    40.0  -0.028862  -0.083380  -0.110180    -0.074141            0.041438
# 5    50.0  -0.034429  -0.094165  -0.131387    -0.086660            0.048913
# 6    60.0  -0.046870  -0.114744  -0.164332    -0.108649            0.058968
# 7    70.0  -0.055359  -0.122869  -0.181421    -0.119883            0.063084
# 8    80.0  -0.065574  -0.135516  -0.199965    -0.133685            0.067215
# 9    90.0  -0.067633  -0.144657  -0.216266    -0.142852            0.074333
# 10  100.0  -0.083582  -0.152371  -0.237645    -0.157866            0.077179
# ...

# %%
# laden BSG-MCT1 export
data_path2 = '/workspaces/EWT/EWT5/data/EWT5_mit_Notizen.ods'
df_E_BSG_MCT1_ilacco1_0 = pd.read_excel(data_path2, engine='odf', sheet_name="Sheet9", skiprows=36)
df_E_BSG_MCT1_ilacco1_1 = pd.read_excel(data_path2, engine='odf', sheet_name="Sheet7", skiprows=36)
df_E_BSG_MCT1_ilacco1_2 = pd.read_excel(data_path2, engine='odf', sheet_name="Sheet8", skiprows=36)
df_E_BSG_MCT1_ilacco1_0_50µM_CCCP = pd.read_excel(data_path2, engine='odf', sheet_name="Sheet10", skiprows=36)
df_E_BSG_MCT1_ilacco1_1_50µM_CCCP = pd.read_excel(data_path2, engine='odf', sheet_name="Sheet11", skiprows=36)
df_E_BSG_MCT1_ilacco1_2_50µM_CCCP = pd.read_excel(data_path2, engine='odf', sheet_name="Sheet12", skiprows=36)
#print(df_E_BSG_MCT1_ilacco1_0)

E_BSG_MCT1_ilacco1_0 = dataframe1(df_E_BSG_MCT1_ilacco1_0,3,5,6,7)
E_BSG_MCT1_ilacco1_1 = dataframe1(df_E_BSG_MCT1_ilacco1_1,3,5,6,7)
E_BSG_MCT1_ilacco1_2 = dataframe1(df_E_BSG_MCT1_ilacco1_2,3,5,6,7)
E_BSG_MCT1_ilacco1_0_50μM_CCCP = dataframe1(df_E_BSG_MCT1_ilacco1_0_50μM_CCCP,3,5,6,7)
E_BSG_MCT1_ilacco1_1_50μM_CCCP = dataframe1(df_E_BSG_MCT1_ilacco1_1_50μM_CCCP,3,5,6,7)
E_BSG_MCT1_ilacco1_2_50μM_CCCP = dataframe1(df_E_BSG_MCT1_ilacco1_2_50μM_CCCP,3,5,6,7)
print(E_BSG_MCT1_ilacco1_0)
# Out:
#      Time  1.Messung  2.Messung  3.Messung  Mittelwerte  Standardabweichung
# 0     0.0   0.000000   0.000000   0.000000     0.000000            0.000000
# 1    13.0  -0.078223  -0.019051  -0.014822    -0.037365            0.035447
# 2    26.0  -0.131309  -0.021763  -0.091476    -0.081516            0.055448
# 3    39.0  -0.144070  -0.066004  -0.142461    -0.117512            0.044614
# 4    52.0  -0.178334  -0.098833  -0.178340    -0.151836            0.045902
# 5    65.0  -0.169319  -0.105733  -0.197068    -0.157373            0.046825
# 6    78.0  -0.180877  -0.128081  -0.213538    -0.174165            0.043122
# 7    91.0  -0.168638  -0.135089  -0.215608    -0.173112            0.040445
# 8   104.0  -0.165982  -0.131835  -0.217749    -0.171855            0.043257
# 9   117.0  -0.164778  -0.144853  -0.219349    -0.176327            0.038567
# 10  130.0  -0.149474  -0.135306  -0.208926    -0.164569            0.039062
# ...

# %%
#EWT 6 data load
data_path3 = '/workspaces/EWT/EWT6/data/ETW6.ods'
df_E_PfFNT_ilacco1_0 = pd.read_excel(data_path3, engine='odf', sheet_name="Sheet12", skiprows=36)
df_E_PfFNT_ilacco1_1 = pd.read_excel(data_path3, engine='odf', sheet_name="Sheet13", skiprows=36)
df_E_PfFNT_ilacco1_2 = pd.read_excel(data_path3, engine='odf', sheet_name="Sheet14", skiprows=36)
df_E_PfFNT_FP_ilacco1_0 = pd.read_excel(data_path3, engine='odf', sheet_name="Sheet15", skiprows=36)
df_E_PfFNT_ilacco1_0_50µM_CCCP = pd.read_excel(data_path3, engine='odf', sheet_name="Sheet16", skiprows=36)
df_E_PfFNT_ilacco1_1_50µM_CCCP = pd.read_excel(data_path3, engine='odf', sheet_name="Sheet17", skiprows=36)
df_E_PfFNT_ilacco1_2_50µM_CCCP = pd.read_excel(data_path3, engine='odf', sheet_name="Sheet18", skiprows=36)
df_E_PfFNT_FP_ilacco1_0_50μM_CCCP = pd.read_excel(data_path3, engine='odf', sheet_name="Sheet19", skiprows=36)
#print(df_E_PfFNT_ilacco1_0)
E_PfFNT_ilacco1_0 = dataframe1(df_E_PfFNT_ilacco1_0,3,5,6,7)
E_PfFNT_ilacco1_1 = dataframe1(df_E_PfFNT_ilacco1_1,3,5,6,7)
E_PfFNT_ilacco1_2 = dataframe1(df_E_PfFNT_ilacco1_2,3,5,6,7)
E_PfFNT_FP_ilacco1_0 = dataframe1(df_E_PfFNT_FP_ilacco1_0,3,5,6,7)
E_PfFNT_ilacco1_0_50μM_CCCP = dataframe1(df_E_PfFNT_ilacco1_0_50μM_CCCP,3,5,6,7)
E_PfFNT_ilacco1_1_50μM_CCCP = dataframe1(df_E_PfFNT_ilacco1_1_50μM_CCCP,3,5,6,7)
E_PfFNT_ilacco1_2_50μM_CCCP = dataframe1(df_E_PfFNT_ilacco1_2_50μM_CCCP,3,5,6,7)
E_PfFNT_FP_ilacco1_0_50μM_CCCP = dataframe1(df_E_PfFNT_FP_ilacco1_0_50μM_CCCP,3,5,6,7)

print(E_PfFNT_ilacco1_1)
# Out:
#      Time  1.Messung  2.Messung  3.Messung  Mittelwerte  Standardabweichung
# 0     0.0   0.000000   0.000000   0.000000     0.000000            0.000000
# 1    13.0  -0.059224  -0.023442  -0.020456    -0.034374            0.021572
# 2    26.0  -0.120579  -0.071751  -0.051509    -0.081280            0.035507
# 3    39.0  -0.126689  -0.060895  -0.051611    -0.079731            0.040930
# 4    52.0  -0.160351  -0.078514  -0.084875    -0.107913            0.045524
# 5    65.0  -0.186698  -0.099045  -0.119689    -0.135144            0.045825
# 6    78.0  -0.203038  -0.128249  -0.139027    -0.156771            0.040429
# 7    91.0  -0.197180  -0.145474  -0.149014    -0.163889            0.028885
# 8   104.0  -0.235019  -0.165914  -0.156815    -0.185916            0.042767
# 9   117.0  -0.267952  -0.204064  -0.190003    -0.220673            0.041544
# 10  130.0  -0.290655  -0.231205  -0.200752    -0.240871            0.045724
# ...

# %%
# Analyse MCT1 Data (linear, erste 30 s)
MCT_df = [('E_MCT1_ilacco1_0', 'o', E_MCT1_ilacco1_0),
          ('E_MCT1_ilacco1_1', '^', E_MCT1_ilacco1_1),
          ('E_MCT1_ilacco1_2', 'v', E_MCT1_ilacco1_2),
          ('E_MCT1_ilacco1_1_50μM_CCCP', 'd', E_MCT1_ilacco1_1_50μM_CCCP)]

MCT1_fit = fit_linear(MCT_df, time_limit=60)
plot_linear_fits(MCT1_fit, 'MCT1 Linear Analysis (0-30s)', 'MCT1_Linear_0_30s.png')
plot_slope_histogram(MCT1_fit, 'MCT1 Steigungen 0-30s.png')
# Out:
# Saved plot: MCT1_Linear_0_30s.png
# Saved slope histogram: MCT1 Steigungen 0-30s.png
#
# === Steigungen-Zusammenfassung (m) ===
# Messung                        m [1/s]
# --------------------------------------------------
# E_MCT1_ilacco1_0               -0.0016 ± 0.0001
# E_MCT1_ilacco1_1               -0.0031 ± 0.0001
# E_MCT1_ilacco1_2               -0.0027 ± 0.0001
# E_MCT1_ilacco1_1_50μM_CCCP     -0.0030 ± 0.0001
# Saved slope histogram: MCT1 Steigungen 0-30s.png
#
# === Steigungen-Zusammenfassung (m) ===
# Messung                        m [1/s]
# --------------------------------------------------
# E_MCT1_ilacco1_0               -0.0016 ± 0.0001
# E_MCT1_ilacco1_1               -0.0031 ± 0.0001
# E_MCT1_ilacco1_2               -0.0027 ± 0.0001
# E_MCT1_ilacco1_1_50μM_CCCP     -0.0030 ± 0.0001
# (<Figure size 1200x600 with 1 Axes>,
#  <Axes: title={'center': 'Vergleich der Steigungen (m)'}, xlabel='Messung', ylabel='Steigung m [1/s]'>)

# %%
#Analyse BSG-MCT1 Data (linear, erste 30 s)
BSG_MCT_df = [('E_BSG_MCT1_ilacco1_0', 'o', E_BSG_MCT1_ilacco1_0),
              ('E_BSG_MCT1_ilacco1_1', '^', E_BSG_MCT1_ilacco1_1),
              ('E_BSG_MCT1_ilacco1_2', 'v', E_BSG_MCT1_ilacco1_2),
              ('E_BSG_MCT1_ilacco1_0_50μM_CCCP', 's', E_BSG_MCT1_ilacco1_0_50μM_CCCP),
              ('E_BSG_MCT1_ilacco1_1_50μM_CCCP', 'd', E_BSG_MCT1_ilacco1_1_50μM_CCCP),
              ('E_BSG_MCT1_ilacco1_2_50μM_CCCP', 'p', E_BSG_MCT1_ilacco1_2_50μM_CCCP)]

BSG_MCT1_fit = fit_linear(BSG_MCT_df, time_limit=60)
plot_linear_fits(BSG_MCT1_fit, 'BSG-MCT1 Linear Analysis (0-60s)', 'BSG_MCT1_Linear_0_60s.png')
plot_slope_histogram(BSG_MCT1_fit, 'BSG_MCT1 Steigungen 0-60s.png')
# Out:
# Saved plot: BSG_MCT1_Linear_0_60s.png
# Saved slope histogram: BSG_MCT1 Steigungen 0-60s.png
#
# === Steigungen-Zusammenfassung (m) ===
# Messung                        m [1/s]
# --------------------------------------------------
# E_BSG_MCT1_ilacco1_0           -0.0030 ± 0.0001
# E_BSG_MCT1_ilacco1_1           -0.0021 ± 0.0002
# E_BSG_MCT1_ilacco1_2           -0.0021 ± 0.0002
# E_BSG_MCT1_ilacco1_0_50μM_CCCP -0.0025 ± 0.0001
# E_BSG_MCT1_ilacco1_1_50μM_CCCP -0.0024 ± 0.0002
# E_BSG_MCT1_ilacco1_2_50μM_CCCP -0.0036 ± 0.0001
# Saved slope histogram: BSG_MCT1 Steigungen 0-60s.png
#
# === Steigungen-Zusammenfassung (m) ===
# Messung                        m [1/s]
# --------------------------------------------------
# E_BSG_MCT1_ilacco1_0           -0.0030 ± 0.0001
# E_BSG_MCT1_ilacco1_1           -0.0021 ± 0.0002
# E_BSG_MCT1_ilacco1_2           -0.0021 ± 0.0002
# E_BSG_MCT1_ilacco1_0_50μM_CCCP -0.0025 ± 0.0001
# E_BSG_MCT1_ilacco1_1_50μM_CCCP -0.0024 ± 0.0002
# ...

# %%
#Analyse PfFNT Data (linear, erste 60 s)
PfFNT_df = [('E_PfFNT_ilacco1_0', 'o', E_PfFNT_ilacco1_0),
           ('E_PfFNT_ilacco1_1', '^', E_PfFNT_ilacco1_1),
           ('E_PfFNT_ilacco1_2', 'v', E_PfFNT_ilacco1_2),
           ('E_PfFNT_FP_ilacco1_0', 's', E_PfFNT_FP_ilacco1_0),
            ('E_PfFNT_ilacco1_0_50μM_CCCP', 'd', E_PfFNT_ilacco1_0_50μM_CCCP),
            ('E_PfFNT_ilacco1_1_50μM_CCCP', 'p', E_PfFNT_ilacco1_1_50μM_CCCP),
            ('E_PfFNT_ilacco1_2_50μM_CCCP', 'h', E_PfFNT_ilacco1_2_50μM_CCCP),
            ('E_PfFNT_FP_ilacco1_0_50μM_CCCP', 'x', E_PfFNT_FP_ilacco1_0_50μM_CCCP)
            ]
PfFNT_fit = fit_linear(PfFNT_df, time_limit=60)
plot_linear_fits(PfFNT_fit, 'PfFNT Linear Analysis (0-60s)', 'PfFNT_Linear_0_60s.png')
plot_slope_histogram(PfFNT_fit, 'PfFNT Steigungen 0-60s.png')
# Out:
# Saved plot: PfFNT_Linear_0_60s.png
# Saved slope histogram: PfFNT Steigungen 0-60s.png
#
# === Steigungen-Zusammenfassung (m) ===
# Messung                        m [1/s]
# --------------------------------------------------
# E_PfFNT_ilacco1_0              -0.0028 ± 0.0001
# E_PfFNT_ilacco1_1              -0.0020 ± 0.0003
# E_PfFNT_ilacco1_2              -0.0027 ± 0.0001
# E_PfFNT_FP_ilacco1_0           -0.0011 ± 0.0002
# E_PfFNT_ilacco1_0_50μM_CCCP    -0.0023 ± 0.0003
# E_PfFNT_ilacco1_1_50μM_CCCP    -0.0033 ± 0.0004
# E_PfFNT_ilacco1_2_50μM_CCCP    -0.0033 ± 0.0002
# E_PfFNT_FP_ilacco1_0_50μM_CCCP -0.0013 ± 0.0002
# Saved slope histogram: PfFNT Steigungen 0-60s.png
#
# === Steigungen-Zusammenfassung (m) ===
# Messung                        m [1/s]
# --------------------------------------------------
# E_PfFNT_ilacco1_0              -0.0028 ± 0.0001
# E_PfFNT_ilacco1_1              -0.0020 ± 0.0003
# E_PfFNT_ilacco1_2              -0.0027 ± 0.0001
# ...

# %%
#Analyse PfFNT_FP Data - Linearer Fit (erste 30 s)
PfFNT_FP_df = [('E_PfFNT_FP_ilacco1_0', 'o', E_PfFNT_FP_ilacco1_0),
               ('E_PfFNT_FP_ilacco1_0_50μM_CCCP', 'd', E_PfFNT_FP_ilacco1_0_50μM_CCCP)]

PfFNT_FP_linear = fit_linear(PfFNT_FP_df, time_limit=30)
plot_linear_fits(PfFNT_FP_linear, 'PfFNT_FP Linear Fit Analysis (0-30s)', 'PfFNT_FP_Linear_0_30s.png')
plot_slope_histogram(PfFNT_FP_linear, 'PfFNT_FP Steigungen 0-30s.png')
# Out:
# Saved plot: PfFNT_FP_Linear_0_30s.png
# Saved slope histogram: PfFNT_FP Steigungen 0-30s.png
#
# === Steigungen-Zusammenfassung (m) ===
# Messung                        m [1/s]
# --------------------------------------------------
# E_PfFNT_FP_ilacco1_0           -0.0015 ± 0.0004
# E_PfFNT_FP_ilacco1_0_50μM_CCCP -0.0017 ± 0.0002
# Saved slope histogram: PfFNT_FP Steigungen 0-30s.png
#
# === Steigungen-Zusammenfassung (m) ===
# Messung                        m [1/s]
# --------------------------------------------------
# E_PfFNT_FP_ilacco1_0           -0.0015 ± 0.0004
# E_PfFNT_FP_ilacco1_0_50μM_CCCP -0.0017 ± 0.0002
# (<Figure size 1200x600 with 1 Axes>,
#  <Axes: title={'center': 'Vergleich der Steigungen (m)'}, xlabel='Messung', ylabel='Steigung m [1/s]'>)

# %%
# Vergleich der Transporter bei ilacco 1_0 (linear 0-60 s)

df = [('E_MCT1_ilacco1_0', 'o', E_MCT1_ilacco1_0),
      ('E_BSG_MCT1_ilacco1_0', 's', E_BSG_MCT1_ilacco1_0),
      ('E_PfFNT_ilacco1_0', '^', E_PfFNT_ilacco1_0),
    ]
fits = fit_linear(df, time_limit=60)
plot_linear_fits(fits, 'Transporter Vergleich ilacco1_0 (0-60s)', 'Transporter_Vergleich_ilacco1_0_linear.png')
plot_slope_histogram(fits, 'Transporter_Vergleich_ilacco1_0_Steigungen.png')
# Out:
# Saved plot: Transporter_Vergleich_ilacco1_0_linear.png
# Saved slope histogram: Transporter_Vergleich_ilacco1_0_Steigungen.png
#
# === Steigungen-Zusammenfassung (m) ===
# Messung                        m [1/s]
# --------------------------------------------------
# E_MCT1_ilacco1_0               -0.0016 ± 0.0001
# E_BSG_MCT1_ilacco1_0           -0.0030 ± 0.0001
# E_PfFNT_ilacco1_0              -0.0028 ± 0.0001
# Saved slope histogram: Transporter_Vergleich_ilacco1_0_Steigungen.png
#
# === Steigungen-Zusammenfassung (m) ===
# Messung                        m [1/s]
# --------------------------------------------------
# E_MCT1_ilacco1_0               -0.0016 ± 0.0001
# E_BSG_MCT1_ilacco1_0           -0.0030 ± 0.0001
# E_PfFNT_ilacco1_0              -0.0028 ± 0.0001
# (<Figure size 1200x600 with 1 Axes>,
#  <Axes: title={'center': 'Vergleich der Steigungen (m)'}, xlabel='Messung', ylabel='Steigung m [1/s]'>)

# %%
# Vergleich der Transporter bei ilacco 1_1 (linear 0-60 s)
df = [('E_MCT1_ilacco1_1', 'o', E_MCT1_ilacco1_1),
      ('E_BSG_MCT1_ilacco1_1', 's', E_BSG_MCT1_ilacco1_1),
      ('E_PfFNT_ilacco1_1', '^', E_PfFNT_ilacco1_1),
    ]
fits = fit_linear(df, time_limit=60)
plot_linear_fits(fits, 'Transporter Vergleich ilacco1_1 (0-60)', 'Transporter_Vergleich_ilacco1_1_linear.png')
plot_slope_histogram(fits, 'Transporter_Vergleich_ilacco1_1_Steigungen.png')
# Out:
# Saved plot: Transporter_Vergleich_ilacco1_1_linear.png
# Saved slope histogram: Transporter_Vergleich_ilacco1_1_Steigungen.png
#
# === Steigungen-Zusammenfassung (m) ===
# Messung                        m [1/s]
# --------------------------------------------------
# E_MCT1_ilacco1_1               -0.0031 ± 0.0001
# E_BSG_MCT1_ilacco1_1           -0.0021 ± 0.0002
# E_PfFNT_ilacco1_1              -0.0020 ± 0.0003
# Saved slope histogram: Transporter_Vergleich_ilacco1_1_Steigungen.png
#
# === Steigungen-Zusammenfassung (m) ===
# Messung                        m [1/s]
# --------------------------------------------------
# E_MCT1_ilacco1_1               -0.0031 ± 0.0001
# E_BSG_MCT1_ilacco1_1           -0.0021 ± 0.0002
# E_PfFNT_ilacco1_1              -0.0020 ± 0.0003
# (<Figure size 1200x600 with 1 Axes>,
#  <Axes: title={'center': 'Vergleich der Steigungen (m)'}, xlabel='Messung', ylabel='Steigung m [1/s]'>)

# %%
# Vergleich der Transporter ilacco 1_2 (linear 0-60 s)
df = [('E_MCT1_ilacco1_2', 'o', E_MCT1_ilacco1_2),
      ('E_BSG_MCT1_ilacco1_2', 's', E_BSG_MCT1_ilacco1_2),
      ('E_PfFNT_ilacco1_2', '^', E_PfFNT_ilacco1_2),
    ]
fits = fit_linear(df, time_limit=60)
plot_linear_fits(fits, 'Transporter Vergleich ilacco1_2 (0-60s)', 'Transporter_Vergleich_ilacco1_2_linear.png')
plot_slope_histogram(fits, 'Transporter_Vergleich_ilacco1_2_Steigungen.png')
# Out:
# Saved plot: Transporter_Vergleich_ilacco1_2_linear.png
# Saved slope histogram: Transporter_Vergleich_ilacco1_2_Steigungen.png
#
# === Steigungen-Zusammenfassung (m) ===
# Messung                        m [1/s]
# --------------------------------------------------
# E_MCT1_ilacco1_2               -0.0027 ± 0.0001
# E_BSG_MCT1_ilacco1_2           -0.0021 ± 0.0002
# E_PfFNT_ilacco1_2              -0.0027 ± 0.0001
# Saved slope histogram: Transporter_Vergleich_ilacco1_2_Steigungen.png
#
# === Steigungen-Zusammenfassung (m) ===
# Messung                        m [1/s]
# --------------------------------------------------
# E_MCT1_ilacco1_2               -0.0027 ± 0.0001
# E_BSG_MCT1_ilacco1_2           -0.0021 ± 0.0002
# E_PfFNT_ilacco1_2              -0.0027 ± 0.0001
# (<Figure size 1200x600 with 1 Axes>,
#  <Axes: title={'center': 'Vergleich der Steigungen (m)'}, xlabel='Messung', ylabel='Steigung m [1/s]'>)
